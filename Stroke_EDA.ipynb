# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rc('patch', edgecolor='black')
sns.set_style('whitegrid')
sns.set_context("notebook", font_scale=1.3, rc={"lines.linewidth": 1.5})
from sklearn import preprocessing 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn import datasets, linear_model, metrics
from sklearn.metrics import  confusion_matrix

# !pip install pycaret
from pycaret.regression import *

import plotly.express as px
import plotly.graph_objects as go
# Out:
# Requirement already satisfied: pycaret in /opt/conda/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: xgboost>=1.1.0 in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.5.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.9/site-packages (from pycaret) (3.7)
# Requirement already satisfied: textblob in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.8.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.3.4)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.9/site-packages (from pycaret) (4.1.2)
# Requirement already satisfied: umap-learn in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.5.2)
# Requirement already satisfied: imbalanced-learn>=0.7.0 in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.9.0)
# Requirement already satisfied: yellowbrick>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.4)
# Requirement already satisfied: plotly>=4.4.1 in /opt/conda/lib/python3.9/site-packages (from pycaret) (5.6.0)
# Requirement already satisfied: mlxtend in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.19.0)
# Requirement already satisfied: mlflow in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.24.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.11.2)
# Requirement already satisfied: scikit-learn>=0.23.2 in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.0.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.9/site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: spacy in /opt/conda/lib/python3.9/site-packages (from pycaret) (3.2.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.20.3)
# Requirement already satisfied: kmodes>=0.10.1 in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.11.1)
# Requirement already satisfied: pyod in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.9.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.0.1)
# Requirement already satisfied: cufflinks>=0.17.0 in /opt/conda/lib/python3.9/site-packages (from pycaret) (0.17.3)
# Requirement already satisfied: pyLDAvis in /opt/conda/lib/python3.9/site-packages (from pycaret) (3.3.1)
# Requirement already satisfied: catboost>=0.23.2 in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.0.4)
# Requirement already satisfied: pandas-profiling>=2.8.0 in /opt/conda/lib/python3.9/site-packages (from pycaret) (3.1.0)
# Requirement already satisfied: IPython in /opt/conda/lib/python3.9/site-packages (from pycaret) (7.29.0)
# Requirement already satisfied: lightgbm>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from pycaret) (3.3.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from pycaret) (3.4.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from catboost>=0.23.2->pycaret) (1.7.2)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.9/site-packages (from catboost>=0.23.2->pycaret) (0.19.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from catboost>=0.23.2->pycaret) (1.15.0)
# Requirement already satisfied: setuptools>=34.4.1 in /opt/conda/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret) (59.1.1)
# Requirement already satisfied: colorlover>=0.2.1 in /opt/conda/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret) (0.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from imbalanced-learn>=0.7.0->pycaret) (3.0.0)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (2.10.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.18.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (5.1.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.1.3)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (3.0.22)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (6.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (5.1.3)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from lightgbm>=2.3.1->pycaret) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.9/site-packages (from pandas->pycaret) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas->pycaret) (2021.3)
# Requirement already satisfied: PyYAML>=5.0.0 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (3.0.3)
# Requirement already satisfied: htmlmin>=0.1.12 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.5.1)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.1.0)
# Requirement already satisfied: multimethod>=1.4 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (1.7)
# Requirement already satisfied: tqdm>=4.48.2 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (4.62.3)
# Requirement already satisfied: markupsafe~=2.0.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (2.0.1)
# Requirement already satisfied: requests>=2.24.0 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (2.26.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.7.4)
# Requirement already satisfied: phik>=0.11.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.12.0)
# Requirement already satisfied: pydantic>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (1.8.2)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (21.2.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (8.4.0)
# Requirement already satisfied: imagehash in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (4.2.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (1.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from gensim->pycaret) (5.2.1)
# Requirement already satisfied: gunicorn in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (20.1.0)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (0.3)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (1.7.5)
# Requirement already satisfied: querystring-parser in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (1.2.4)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (8.0.3)
# Requirement already satisfied: sqlparse>=0.3.1 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (0.4.2)
# Requirement already satisfied: databricks-cli>=0.8.7 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (0.16.4)
# Requirement already satisfied: gitpython>=2.1.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (3.1.27)
# Requirement already satisfied: prometheus-flask-exporter in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (0.19.0)
# Requirement already satisfied: Flask in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (2.0.3)
# Requirement already satisfied: docker>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (5.0.3)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (1.4.27)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (21.2)
# Requirement already satisfied: protobuf>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (3.16.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (4.8.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.9/site-packages (from nltk->pycaret) (2022.3.2)
# Requirement already satisfied: numexpr in /opt/conda/lib/python3.9/site-packages (from pyLDAvis->pycaret) (2.7.3)
# Requirement already satisfied: funcy in /opt/conda/lib/python3.9/site-packages (from pyLDAvis->pycaret) (1.17)
# Requirement already satisfied: future in /opt/conda/lib/python3.9/site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: sklearn in /opt/conda/lib/python3.9/site-packages (from pyLDAvis->pycaret) (0.0)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.9/site-packages (from pyod->pycaret) (0.13.1)
# Requirement already satisfied: numba>=0.35 in /opt/conda/lib/python3.9/site-packages (from pyod->pycaret) (0.54.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (0.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (3.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (2.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (8.0.13)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (1.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (0.9.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (0.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (1.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (2.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.9/site-packages (from spacy->pycaret) (0.6.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.9/site-packages (from umap-learn->pycaret) (0.5.6)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.9/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.9/site-packages (from docker>=4.0.0->mlflow->pycaret) (1.2.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.9/site-packages (from gitpython>=2.1.0->mlflow->pycaret) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.6.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (7.0.6)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from jedi>=0.16->IPython->pycaret) (0.8.2)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.2.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /opt/conda/lib/python3.9/site-packages (from numba>=0.35->pyod->pycaret) (0.37.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.9/site-packages (from pexpect>4.3->IPython->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret) (3.7.4.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.1)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.5)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.9/site-packages (from alembic->mlflow->pycaret) (1.1.5)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from sqlalchemy->mlflow->pycaret) (1.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/lib/python3.9/site-packages (from Flask->mlflow->pycaret) (2.1.1)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/conda/lib/python3.9/site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.9/site-packages (from prometheus-flask-exporter->mlflow->pycaret) (0.12.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/conda/lib/python3.9/site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->pycaret) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (22.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.12.1)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.3.0)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.9/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (1.2.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.15.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.8)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.21)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)

# %%
#loading the csv file
dataset=pd.read_csv('./input/stroke.csv')

# %%
#value_count
dataset.value_counts()
# Out:
# id     gender  age   hypertension  heart_disease  ever_married  work_type      Residence_type  avg_glucose_level  bmi   smoking_status   stroke
# 77     Female  13.0  0             0              No            children       Rural           85.81              18.6  Unknown          0         1
# 49605  Male    63.0  0             0              Yes           Private        Urban           74.39              31.0  formerly smoked  0         1
# 49661  Male    53.0  0             0              Yes           Govt_job       Urban           85.17              29.2  never smoked     0         1
# 49646  Male    72.0  0             1              Yes           Self-employed  Rural           113.63             26.5  Unknown          0         1
# 49645  Male    58.0  0             0              No            Private        Rural           76.22              22.2  formerly smoked  0         1
#                                                                                                                                                   ..
# 25138  Female  78.0  1             0              Yes           Private        Rural           91.63              33.5  smokes           0         1
# 25130  Female  27.0  0             0              Yes           Private        Urban           79.21              19.5  Unknown          0         1
# 25107  Female  47.0  0             0              Yes           Private        Urban           65.04              30.9  never smoked     0         1
# 25102  Female  51.0  0             0              Yes           Govt_job       Urban           95.16              42.7  formerly smoked  0         1
# 72940  Female  2.0   0             0              No            children       Urban           102.92             17.6  Unknown          0         1
# Length: 4909, dtype: int64

# %%
#finding the shape of the dataset rows, cloumns
dataset.shape
# Out:
# (5110, 12)

# %%
#displaying the column names 
dataset.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
#finding the unique values
dataset.nunique()
# Out:
# id                   5110
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
#statistics
dataset.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
#cleaning the data
#to check whether null values are present
dataset.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
#relationship analysis
#correlation analysis
cor = dataset.corr()
cor
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.003084  0.333398      0.167811       0.041357
# stroke             0.006388  0.245257      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.003084  0.006388
# age                         0.238171  0.333398  0.245257
# hypertension                0.174474  0.167811  0.127904
# heart_disease               0.161857  0.041357  0.134914
# avg_glucose_level           1.000000  0.175502  0.131945
# bmi                         0.175502  1.000000  0.042374
# stroke                      0.131945  0.042374  1.000000

# %%
#plotting the correlation in the dataset
sns.heatmap(cor, xticklabels = cor.columns, yticklabels = cor.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
#visualization for seeing the correlation
sns.pairplot(dataset)

# %%
#visulaisation
plt.figure(figsize=(10,5))
sns.barplot(x= dataset['gender'],y= dataset['heart_disease'])
plt.xticks(rotation=90)
plt.show()

# %%
#visulaisation
plt.figure(figsize=(10,5))
sns.barplot(x= dataset['gender'],y= dataset['hypertension'])
plt.xticks(rotation=90)
plt.show()

# %%
#visulaisation
plt.figure(figsize=(10,5))
sns.barplot(x= dataset['gender'],y= dataset['stroke'])
plt.xticks(rotation=90)
plt.show()

# %%
#visulaisation
plt.figure(figsize=(10,5))
sns.barplot(x= dataset['gender'],y= dataset['heart_disease'])
plt.xticks(rotation=90)
plt.show()

# %%
#visulaisation
plt.figure(figsize=(10,5))
sns.barplot(x= dataset['gender'],y= dataset['avg_glucose_level'])
plt.xticks(rotation=90)
plt.show()

# %%
#visulaisation
plt.figure(figsize=(10,5))
sns.barplot(x= dataset['age'],y= dataset['stroke'])
plt.xticks(rotation=90)
plt.show()

# %%
#Correlation function
def corrMat(dataset,id=False):
    
    corr_mat = dataset.corr().round(2)
    f, ax = plt.subplots(figsize=(12,7))
    mask = np.triu(np.ones_like(corr_mat, dtype=bool))
    mask = mask[1:,:-1]
    corr = corr_mat.iloc[1:,:-1].copy()
    sns.heatmap(corr,mask=mask,vmin=-0.3,vmax=0.3,center=0, 
                cmap='RdPu_r',square=False,lw=2,annot=True,cbar=False)
#     bottom, top = ax.get_ylim() 
#     ax.set_ylim(bottom + 0.5, top - 0.5) 
    ax.set_title('Shifted Linear Correlation Matrix')
    
corrMat(dataset.drop(['bmi'],axis = 1))

# %%
 # Plotting the Active cases per states
dataset.plot(kind='bar', x='gender', y='stroke',color="red", figsize=(15,6),
        title="Active cases by states", ylabel="Number of active cases")

# %%
#Statistics
dataset.describe().T.style.bar(subset=['mean'], color='#606ff2')\
                            .background_gradient(subset=['std'], cmap='PuBu')\
                            .background_gradient(subset=['50%'], cmap='PuBu')

# %%
#Correlation 
background_color = "#f6f5f5"

fig = plt.figure(figsize=(18, 8), facecolor=background_color)
gs = fig.add_gridspec(1, 1)
ax0 = fig.add_subplot(gs[0, 0])

colors = ["#ff355d", "#f6f5f5","#ff355d"]
colormap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

ax0.set_facecolor(background_color)
ax0.text(0, -0.5, 'Features Correlation on Train Dataset', fontsize=15, fontweight='bold',bbox=dict(facecolor='none', edgecolor='black', boxstyle='round', linewidth=1.5))
ax0.text(0, -0.2, 'Highest correlation in the dataset is 0.9', fontsize=9, fontweight='light')

sns.heatmap(dataset.corr(), ax=ax0, vmin=-1, vmax=1, annot=True, square=True, 
            cbar_kws={"orientation": "horizontal"}, cbar=False, cmap=colormap, fmt='.1f')
plt.show()
